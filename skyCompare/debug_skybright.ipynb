# %%
# %matplotlib inline
import lsst.sims.skybrightness as sb
import lsst.sims.photUtils.Bandpass as Bandpass
import os
import numpy as np
import matplotlib.pylab as plt
import healpy as hp

# %%
nside = 16
hpmap = np.zeros(hp.nside2npix(nside))
lat, ra = hp.pix2ang(nside, np.arange(hpmap.size))
dec = np.pi/2-lat

# %%
sm = sb.SkyModel(mags=True, preciseAltAz=True)
mjd = 59657.223625
sm.setRaDecMjd(ra,dec,mjd)
# Out:
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)" [astropy._erfa.core]
# /Users/yoachim/gitRepos/sims_utils/python/lsst/sims/utils/ModifiedJulianDate.py:191: UTCtoUT1Warning: UTC is outside of IERS table for UT1-UTC.
# Returning UT1 = UTC for lack of a better idea
# This warning was caused by calling ModifiedJulianDate.dut1
#
#   category=UTCtoUT1Warning)
# /Users/yoachim/gitRepos/sims_utils/python/lsst/sims/utils/ModifiedJulianDate.py:191: UTCtoUT1Warning: UTC is outside of IERS table for UT1-UTC.
# Returning UT1 = UTC for lack of a better idea
# This warning was caused by calling ModifiedJulianDate.UT1
#
#   category=UTCtoUT1Warning)

# %%
mags = sm.returnMags()

# %%
mags
# Out:
# {'g': array([         nan,          nan,          nan, ...,  17.94422311,
#          17.95812939,  17.9157154 ]),
#  'i': array([         nan,          nan,          nan, ...,  18.37073902,
#          18.3799028 ,  18.32856067]),
#  'r': array([         nan,          nan,          nan, ...,  18.15450384,
#          18.16576076,  18.12337908]),
#  'u': array([         nan,          nan,          nan, ...,  18.38003612,
#          18.39343776,  18.35789039]),
#  'y': array([         nan,          nan,          nan, ...,  17.42481695,
#          17.43529731,  17.34042331]),
#  'z': array([         nan,          nan,          nan, ...,  18.17930112,
#          18.18852581,  18.11606394])}

# %%
hp.mollview(mags['r'])
