# %% [markdown]
# Make a map of the total number of visits

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.db as db

# %%
# Set the database and query
database = 'enigma_1189_sqlite.db'
opsdb = db.OpsimDatabase(database)
outDir = 'Nvis'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
metric = metrics.CountMetric(col='expMJD', units='Number of Visits')
#slicer = slicers.HealpixSlicer(nside=128, lonCol='ditheredRA', latCol='ditheredDec')
slicer=slicers.OpsimFieldSlicer()
sql = ''
plotDict={'colorMax':2000,'colorMin':0}
bundle = metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict)

# %%
bg = metricBundles.MetricBundleGroup({0:bundle},opsdb, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
# Out:
# Querying database with no constraint.
# Found 2469307 visits
# Running:  [0]
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Warning: this OpsimFieldSlicer was already set up. Re-setting up an OpsimFieldSlicer can change the field information. Rerun metrics if this was intentional.

# %%
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with  sqlconstraint now.
# Plotting complete.
# Optimal bin calculation tried to make 316 bins, returning 200

# %%
# adjust the color max
bundle.plotDict['colorMax'] = 1400
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with  sqlconstraint now.
# Plotting complete.
# Optimal bin calculation tried to make 316 bins, returning 200

# %%
# Change the color map
bundle.plotDict['cmap'] = 'jet'
bg.plotAll(closefigs=False)
# Out:
# Plotting figures with  sqlconstraint now.
# Plotting complete.
# Optimal bin calculation tried to make 316 bins, returning 200
