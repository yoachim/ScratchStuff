# %%
# %matplotlib inline
import numpy as np
import healpy as hp
from thomson import *
from fib_sphere_grid import fib_sphere_grid
from healpyUtils import *

# %%
ra, dec = fib_sphere_grid(10)

# %%
hp.mollview(_healbin(ra,dec, dec*0+1, nside=16, reduceFunc=np.size))

# %%
fib_points = np.hstack((ra,dec))
haver_opt = minimize(haver_potential, fib_points)

# %%
haver_ra, haver_dec = limit_wrap(haver_opt.x[0:haver_opt.x.size/2], haver_opt.x[haver_opt.x.size/2:])
hp.mollview(_healbin(haver_ra,haver_dec, dec*0+1, nside=16, reduceFunc=np.size))

# %%
haver_potential(fib_points)
# Out:
# 82.619844960995039

# %%
haver_potential(haver_opt.x)
# Out:
# 58.428434125451957

# %%
reg_opt = minimize(points_on_sphere_potential, fib_points)
reg_ra = reg_opt.x[0:reg_opt.x.size/2]
reg_dec = reg_opt.x[reg_opt.x.size/2:]

# %%
haver_potential(fib_points)
# Out:
# 82.619844960995039

# %%
points_on_sphere_potential(fib_points)
# Out:
# 334.63208849882483

# %%
reg_ra, reg_dec = limit_wrap(reg_opt.x[0:reg_opt.x.size/2], reg_opt.x[reg_opt.x.size/2:])
hp.mollview(_healbin(reg_ra,reg_dec, dec*0+1, nside=16, reduceFunc=np.size))

# %%
fib_ra = fib_points[0:fib_points.size/2]
fib_dec = fib_points[fib_points.size/2:]
