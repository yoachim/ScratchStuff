# %%
# %matplotlib inline
import lsst.sims.maf.db as db
import lsst.sims.maf.metricBundles as metricBundles
from lsst.sims.maf.bundles import glanceBundle

# %%
conn = db.Database('observations.sqlite')
outDir='Glance'
colmap = {'ra': 'ra', 'dec': 'dec', 'mjd': 'mjd',
              'exptime': 'exptime', 'visittime': 'exptime', 'alt': 'alt',
              'az': 'az', 'filter': 'filter', 'fiveSigmaDepth': 'fivesigmadepth',
              'night': 'night', 'slewtime': 'slewtime', 'seeingGeom': 'seeing'}

gb = glanceBundle(colmap_dict=colmap)
outDir='Glance'
resultsDb = db.ResultsDb(outDir=outDir)

group = metricBundles.MetricBundleGroup(gb, conn, outDir=outDir, resultsDb=resultsDb, 
                                        runName='roth_1')
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:118: UserWarning: Changing runName opsim to roth_1
#   warnings.warn('Changing runName %s to %s' % (bundleDict[bk].runName, runName))

# %%
group.runAll()
# Out:
# Querying database observations with no constraint for columns ['night', 'dec', 'fivesigmadepth', 'ra', 'az', 'seeing', 'mjd', 'slewtime', 'exptime', 'alt', 'filter'].
# Found 2922451 visits
# Running:  ['opsim_Length_of_Survey_days_UNIS', 'opsim_NChanges_filter_mjd_UNIS', 'opsim_OpenShutterFraction_UNIS', 'opsim_tEff_UNIS', 'opsim_Number_of_Exposures_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_HEAL']
# Completed metric generation.
# Running:  ['opsim_OpenShutterFraction_ONED']
# Completed metric generation.
# Running:  ['opsim_Filter_Changes_ONED']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/slicers/oneDSlicer.py:74: UserWarning: Both binsize and bins have been set; Using binsize 1.000000 only.
#   warnings.warn('Both binsize and bins have been set; Using binsize %f only.' %(self.binsize))
# Completed metric generation.
# Running:  ['opsim_Slew_Time_Histogram_ONED']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_HEAL', 'opsim_CoaddM5_HEAL', 'opsim_parallax_HEAL', 'opsim_properMotion_HEAL']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/astrometryUtils.py:72: RuntimeWarning: divide by zero encountered in true_divide
#   result = fwhm/(snr)
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="g" or filter="r" or filter="i" for columns ['dec', 'ra', 'mjd']
# Found 1556315 visits
# Running:  ['opsim_PairFraction_g_or_r_or_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="y" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# Found 409278 visits
# Running:  ['opsim_tEff_y_UNIS', 'opsim_Number_of_Exposures_y_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_y_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_y_HEAL', 'opsim_CoaddM5_y_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="r" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# Found 529477 visits
# Running:  ['opsim_tEff_r_UNIS', 'opsim_Number_of_Exposures_r_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_r_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_r_HEAL', 'opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="i" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# Found 481397 visits
# Running:  ['opsim_tEff_i_UNIS', 'opsim_Number_of_Exposures_i_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_i_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_i_HEAL', 'opsim_CoaddM5_i_HEAL']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metrics/simpleMetrics.py:36: RuntimeWarning: divide by zero encountered in log10
#   return 1.25 * np.log10(np.sum(10.**(.8*dataSlice[self.colname])))
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="z" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/numpy/core/_methods.py:112: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metrics/simpleMetrics.py:243: RuntimeWarning: invalid value encountered in greater
#   outsiders = np.where(dataSlice[self.colname] > boundary)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metrics/simpleMetrics.py:246: RuntimeWarning: invalid value encountered in less
#   outsiders = np.where(dataSlice[self.colname] < boundary)
# Found 422795 visits
# Running:  ['opsim_tEff_z_UNIS', 'opsim_Number_of_Exposures_z_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_z_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_z_HEAL', 'opsim_CoaddM5_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="u" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# Found 534063 visits
# Running:  ['opsim_tEff_u_UNIS', 'opsim_Number_of_Exposures_u_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_u_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_u_HEAL', 'opsim_CoaddM5_u_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint filter="g" for columns ['dec', 'fivesigmadepth', 'ra', 'az', 'mjd', 'alt', 'filter']
# Found 545441 visits
# Running:  ['opsim_tEff_g_UNIS', 'opsim_Number_of_Exposures_g_UNIS']
# Completed metric generation.
# Running:  ['opsim_Nvisits_as_function_of_Alt_Az_g_HEAL']
# Completed metric generation.
# Running:  ['opsim_Count_mjd_g_HEAL', 'opsim_CoaddM5_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
group.plotAll(closefigs=False)
# Out:
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 467 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 878.429  dipole: lon: -79.3178, lat: -87.6215, amp: 62.695
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 316 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 27.4863  dipole: lon: -119.046, lat: -78.6427, amp: 0.211263
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 584 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.723176  dipole: lon: -14.8605, lat: 86.0572, amp: 0.248588
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 2003 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.165529  dipole: lon: 67.9731, lat: 84.5247, amp: 0.0308945
# Plotting complete.
# Plotting figures with "filter="g" or filter="r" or filter="i"" constraint now.
# monopole: 0.607327  dipole: lon: -114.545, lat: 79.409, amp: 0.0960958
# Plotting complete.
# Plotting figures with "filter="y"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 253 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 119.946  dipole: lon: 108.451, lat: -77.3937, amp: 22.4066
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 267 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 24.5022  dipole: lon: -177.7, lat: -86.0423, amp: 0.297311
# Plotting complete.
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 162.022  dipole: lon: -81.5791, lat: 7.53751, amp: 5.38093
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 557 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 26.7655  dipole: lon: -112.092, lat: -79.5431, amp: 0.185385
# Plotting complete.
# Plotting figures with "filter="i"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 364 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 144.897  dipole: lon: -131.943, lat: -65.9538, amp: 10.3809
# /Users/yoachim/lsstp3/DarwinX86/healpy/1.10.3.lsst1/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1049: RuntimeWarning: invalid value encountered in less
#   result.data[result.data<0]=0.0
# /Users/yoachim/lsstp3/DarwinX86/healpy/1.10.3.lsst1/lib/python/healpy-1.10.3-py3.6-macosx-10.7-x86_64.egg/healpy/projaxes.py:1050: RuntimeWarning: invalid value encountered in greater
#   result.data[result.data>1]=1.0
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/colors.py:496: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 311 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 26.1938  dipole: lon: -138.402, lat: -79.738, amp: 0.217731
# Plotting complete.
# Plotting figures with "filter="z"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 121.711  dipole: lon: 164.43, lat: -80.2532, amp: 32.2474
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 231 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 25.5309  dipole: lon: -163.681, lat: -83.4091, amp: 0.313567
# Plotting complete.
# Plotting figures with "filter="u"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 246 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 163.221  dipole: lon: 24.3969, lat: -0.153205, amp: 6.51437
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 248 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 25.8453  dipole: lon: -127.875, lat: -74.671, amp: 0.24073
# Plotting complete.
# Plotting figures with "filter="g"" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 166.633  dipole: lon: -40.7381, lat: -3.60538, amp: 4.49662
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:60: UserWarning: Optimal bin calculation tried to make 463 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 27.168  dipole: lon: -117.637, lat: -75.3557, amp: 0.20044
# Plotting complete.
