# %%
# %matplotlib inline
import numpy as np

import lsst.sims.maf.utils as mafUtils
import lsst.sims.maf.db as db
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import lsst.sims.maf.plots as plots

import matplotlib.pylab as plt

# %%
databases = []
databases.append(db.Database('feature_baseline_10yrs.db', defaultTable='observations'))
databases.append(db.Database('feature_rolling_half_10yrs.db', defaultTable='observations'))
databases.append(db.Database('feature_rolling_half_mask_10yrs.db', defaultTable='observations'))
databases.append(db.Database('feature_rolling_third_10yrs.db', defaultTable='observations'))
databases.append(db.Database('feature_rolling_twoThird_10yrs.db', defaultTable='observations'))
names = ['baseline', 'half', 'half mask', 'third', 'two thirds']
#names = ['baseline', 'half mask']

# %%
for name, database in zip(names, databases):
#for name, database in zip([names[0]], [databases[0]]):
    bundleList = []
    for year in [1,2,3,4,5,6]:
    #for year in [1]:
        slicer = slicers.HealpixSlicer(lonCol='RA', latCol='dec')
        metric = metrics.CountMetric(col='RA')
        sql='night > %i and night < %i' % ((year-1)*365.25, year*365.25)
        plotDict={'title':'%s, year %i' % (name, year), 'percentileClip':95.}
        bundleList.append(metricBundles.MetricBundle(metric, slicer, sql, plotDict=plotDict,
                                                     plotFuncs=[plots.HealpixSkyMap()]))
    bd = metricBundles.makeBundlesDictFromList(bundleList)
    mb = metricBundles.MetricBundleGroup(bd, database)
    mb.runAll()
    mb.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database observations with constraint night > 730 and night < 1095 for columns ['RA', 'dec']
# Found 219787 visits
# Running:  ['opsim_Count_RA_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1095 and night < 1461 for columns ['RA', 'dec']
# Found 232942 visits
# Running:  ['opsim_Count_RA_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 365 and night < 730 for columns ['RA', 'dec']
# Found 227838 visits
# Running:  ['opsim_Count_RA_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 0 and night < 365 for columns ['RA', 'dec']
# Found 238146 visits
# Running:  ['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1826 and night < 2191 for columns ['RA', 'dec']
# Found 232823 visits
# Running:  ['opsim_Count_RA_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1461 and night < 1826 for columns ['RA', 'dec']
# Found 236433 visits
# Running:  ['opsim_Count_RA_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# Plotting complete.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database observations with constraint night > 730 and night < 1095 for columns ['RA', 'dec']
# Found 216890 visits
# Running:  ['opsim_Count_RA_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1095 and night < 1461 for columns ['RA', 'dec']
# Found 231601 visits
# Running:  ['opsim_Count_RA_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 365 and night < 730 for columns ['RA', 'dec']
# Found 226962 visits
# Running:  ['opsim_Count_RA_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 0 and night < 365 for columns ['RA', 'dec']
# Found 233585 visits
# Running:  ['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1826 and night < 2191 for columns ['RA', 'dec']
# Found 231410 visits
# Running:  ['opsim_Count_RA_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1461 and night < 1826 for columns ['RA', 'dec']
# Found 232276 visits
# Running:  ['opsim_Count_RA_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# Plotting complete.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database observations with constraint night > 730 and night < 1095 for columns ['RA', 'dec']
# Found 215960 visits
# Running:  ['opsim_Count_RA_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1095 and night < 1461 for columns ['RA', 'dec']
# Found 233599 visits
# Running:  ['opsim_Count_RA_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 365 and night < 730 for columns ['RA', 'dec']
# Found 229278 visits
# Running:  ['opsim_Count_RA_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 0 and night < 365 for columns ['RA', 'dec']
# Found 233585 visits
# Running:  ['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1826 and night < 2191 for columns ['RA', 'dec']
# Found 232652 visits
# Running:  ['opsim_Count_RA_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1461 and night < 1826 for columns ['RA', 'dec']
# Found 232426 visits
# Running:  ['opsim_Count_RA_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# Plotting complete.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database observations with constraint night > 730 and night < 1095 for columns ['RA', 'dec']
# Found 217033 visits
# Running:  ['opsim_Count_RA_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1095 and night < 1461 for columns ['RA', 'dec']
# Found 229383 visits
# Running:  ['opsim_Count_RA_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 365 and night < 730 for columns ['RA', 'dec']
# Found 228788 visits
# Running:  ['opsim_Count_RA_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 0 and night < 365 for columns ['RA', 'dec']
# Found 233529 visits
# Running:  ['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1826 and night < 2191 for columns ['RA', 'dec']
# Found 229804 visits
# Running:  ['opsim_Count_RA_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1461 and night < 1826 for columns ['RA', 'dec']
# Found 236679 visits
# Running:  ['opsim_Count_RA_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database observations with constraint night > 730 and night < 1095 for columns ['RA', 'dec']
# Found 212884 visits
# Running:  ['opsim_Count_RA_night_gt_730_and_night_lt_1095_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1095 and night < 1461 for columns ['RA', 'dec']
# Found 225548 visits
# Running:  ['opsim_Count_RA_night_gt_1095_and_night_lt_1461_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 365 and night < 730 for columns ['RA', 'dec']
# Found 226420 visits
# Running:  ['opsim_Count_RA_night_gt_365_and_night_lt_730_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 0 and night < 365 for columns ['RA', 'dec']
# Found 228741 visits
# Running:  ['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1826 and night < 2191 for columns ['RA', 'dec']
# Found 224075 visits
# Running:  ['opsim_Count_RA_night_gt_1826_and_night_lt_2191_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database observations with constraint night > 1461 and night < 1826 for columns ['RA', 'dec']
# Found 234390 visits
# Running:  ['opsim_Count_RA_night_gt_1461_and_night_lt_1826_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "night > 730 and night < 1095" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 1095 and night < 1461" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 365 and night < 730" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 0 and night < 365" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 1826 and night < 2191" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.
# Plotting figures with "night > 1461 and night < 1826" constraint now.
# /Users/yoachim/lsstp3/DarwinX86/miniconda3/4.2.12.lsst1/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Plotting complete.

# %%
plt.hist(bd['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL'].metricValues, bins=200)
# Out:
# (array([  1.15606000e+05,   4.07600000e+03,   9.02800000e+03,
#           2.17830000e+04,   7.60900000e+03,   7.27400000e+03,
#           1.11020000e+04,   1.17830000e+04,   7.25200000e+03,
#           9.02000000e+02,   1.00000000e+01,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   2.30000000e+01,
#           2.60000000e+01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   4.20000000e+01,
#           0.00000000e+00,   0.00000000e+00,   4.70000000e+01,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.70000000e+01,
#           1.00000000e+01,   1.70000000e+01]),
#  array([  1.83142544e-04,   2.35651822e+01,   4.71301813e+01,
#           7.06951804e+01,   9.42601795e+01,   1.17825179e+02,
#           1.41390178e+02,   1.64955177e+02,   1.88520176e+02,
#           2.12085175e+02,   2.35650174e+02,   2.59215173e+02,
#           2.82780172e+02,   3.06345171e+02,   3.29910170e+02,
#           3.53475169e+02,   3.77040168e+02,   4.00605168e+02,
#           4.24170167e+02,   4.47735166e+02,   4.71300165e+02,
#           4.94865164e+02,   5.18430163e+02,   5.41995162e+02,
#           5.65560161e+02,   5.89125160e+02,   6.12690159e+02,
#           6.36255158e+02,   6.59820158e+02,   6.83385157e+02,
#           7.06950156e+02,   7.30515155e+02,   7.54080154e+02,
#           7.77645153e+02,   8.01210152e+02,   8.24775151e+02,
#           8.48340150e+02,   8.71905149e+02,   8.95470148e+02,
#           9.19035147e+02,   9.42600147e+02,   9.66165146e+02,
#           9.89730145e+02,   1.01329514e+03,   1.03686014e+03,
#           1.06042514e+03,   1.08399014e+03,   1.10755514e+03,
#           1.13112014e+03,   1.15468514e+03,   1.17825014e+03,
#           1.20181514e+03,   1.22538014e+03,   1.24894513e+03,
#           1.27251013e+03,   1.29607513e+03,   1.31964013e+03,
#           1.34320513e+03,   1.36677013e+03,   1.39033513e+03,
#           1.41390013e+03,   1.43746513e+03,   1.46103013e+03,
#           1.48459513e+03,   1.50816012e+03,   1.53172512e+03,
#           1.55529012e+03,   1.57885512e+03,   1.60242012e+03,
#           1.62598512e+03,   1.64955012e+03,   1.67311512e+03,
#           1.69668012e+03,   1.72024512e+03,   1.74381012e+03,
#           1.76737511e+03,   1.79094011e+03,   1.81450511e+03,
#           1.83807011e+03,   1.86163511e+03,   1.88520011e+03,
#           1.90876511e+03,   1.93233011e+03,   1.95589511e+03,
#           1.97946011e+03,   2.00302511e+03,   2.02659010e+03,
#           2.05015510e+03,   2.07372010e+03,   2.09728510e+03,
#           2.12085010e+03,   2.14441510e+03,   2.16798010e+03,
#           2.19154510e+03,   2.21511010e+03,   2.23867510e+03,
#           2.26224010e+03,   2.28580509e+03,   2.30937009e+03,
#           2.33293509e+03,   2.35650009e+03,   2.38006509e+03,
#           2.40363009e+03,   2.42719509e+03,   2.45076009e+03,
#           2.47432509e+03,   2.49789009e+03,   2.52145509e+03,
#           2.54502008e+03,   2.56858508e+03,   2.59215008e+03,
#           2.61571508e+03,   2.63928008e+03,   2.66284508e+03,
#           2.68641008e+03,   2.70997508e+03,   2.73354008e+03,
#           2.75710508e+03,   2.78067008e+03,   2.80423507e+03,
#           2.82780007e+03,   2.85136507e+03,   2.87493007e+03,
#           2.89849507e+03,   2.92206007e+03,   2.94562507e+03,
#           2.96919007e+03,   2.99275507e+03,   3.01632007e+03,
#           3.03988507e+03,   3.06345006e+03,   3.08701506e+03,
#           3.11058006e+03,   3.13414506e+03,   3.15771006e+03,
#           3.18127506e+03,   3.20484006e+03,   3.22840506e+03,
#           3.25197006e+03,   3.27553506e+03,   3.29910005e+03,
#           3.32266505e+03,   3.34623005e+03,   3.36979505e+03,
#           3.39336005e+03,   3.41692505e+03,   3.44049005e+03,
#           3.46405505e+03,   3.48762005e+03,   3.51118505e+03,
#           3.53475005e+03,   3.55831504e+03,   3.58188004e+03,
#           3.60544504e+03,   3.62901004e+03,   3.65257504e+03,
#           3.67614004e+03,   3.69970504e+03,   3.72327004e+03,
#           3.74683504e+03,   3.77040004e+03,   3.79396504e+03,
#           3.81753003e+03,   3.84109503e+03,   3.86466003e+03,
#           3.88822503e+03,   3.91179003e+03,   3.93535503e+03,
#           3.95892003e+03,   3.98248503e+03,   4.00605003e+03,
#           4.02961503e+03,   4.05318003e+03,   4.07674502e+03,
#           4.10031002e+03,   4.12387502e+03,   4.14744002e+03,
#           4.17100502e+03,   4.19457002e+03,   4.21813502e+03,
#           4.24170002e+03,   4.26526502e+03,   4.28883002e+03,
#           4.31239502e+03,   4.33596001e+03,   4.35952501e+03,
#           4.38309001e+03,   4.40665501e+03,   4.43022001e+03,
#           4.45378501e+03,   4.47735001e+03,   4.50091501e+03,
#           4.52448001e+03,   4.54804501e+03,   4.57161001e+03,
#           4.59517500e+03,   4.61874000e+03,   4.64230500e+03,
#           4.66587000e+03,   4.68943500e+03,   4.71300000e+03]),
#  <a list of 200 Patch objects>)

# %%
bd['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL'].metricValues.max()
# Out:
# 4713.0

# %%
from lsst.sims.maf.utils import percentileClipping

# %%
percentileClipping(bd['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL'].metricValues, percentile=90.)
# Out:
# (185.0, 0.60435801300936065)

# %%
bd['opsim_Count_RA_night_gt_0_and_night_lt_365_HEAL'].metricValues
# Out:
# masked_array(data = [-- -- -- ..., 125.0 132.0 140.0],
#              mask = [ True  True  True ..., False False False],
#        fill_value = -1.6375e+30)
